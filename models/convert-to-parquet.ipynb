# %%
import pandas as pd
import seaborn as sns
import pyarrow
from matplotlib import pyplot

# %%
df = pd.read_excel('airportposition.xlsx')

# %%
# Out:
#        Rec #.      id ident           type  \
# 0           1    6523   00A       heliport
# 1           2  323361  00AA  small_airport
# 2           3    6524  00AK  small_airport
# 3           4    6525  00AL  small_airport
# 4           5    6526  00AR         closed
# ...       ...     ...   ...            ...
# 55787   55778  317861  ZYYK  medium_airpor
# 55788   55779   32753  ZYYY  medium_airpor
# 55789   55780   46378  ZZ-0       heliport
# 55790   55781  307326  ZZ-0  small_airport
# 55791   55782  313629  ZZZZ  small_airport
#
#                                      name  latitude_deg  longitude_deg  \
# 0                       Total Rf Heliport     40.070801     -74.933601
# 1                    Aero B Ranch Airport     38.704022    -101.473911
# 2                            Lowell Field     59.949200    -151.695999
# 3                            Epps Airpark     34.864799     -86.770302
# 4      Newport Hospital & Clinic Heliport     35.608700     -91.254898
# ...

# %%
df.to_parquet('airportposition.parquet')

# %%
countryFreq = df.iso_country.value_counts()

# %%
countryFreq.columns = ['country','count']

# %%
countryFreq = countryFreq[countryFreq > 1]

# %%
countryFreq[countryFreq > 100]
# Out:
# US    22845
# BR     4534
# CA     2791
# AU     1943
# KR     1371
# MX     1303
# RU     1071
# GB     1054
# DE      954
# FR      862
# AR      847
# CO      705
# IT      683
# PG      596
# VE      592
# ZA      491
# CL      480
# ID      473
# ES      441
# CN      408
# KE      371
# IN      339
# CD      285
# PH      281
# PL      280
# CZ      270
# JP      233
# SE      227
# PT      217
# NZ      211
# TZ      207
# NO      197
# BO      196
# UA      194
# UZ      176
# PE      173
# HN      158
# BE      146
# AT      145
# ZW      139
# IR      136
# PK      136
# BG      136
# CU      134
# CR      132
# BW      127
# KZ      127
# TR      124
# EC      123
# DK      119
# FI      111
# HU      111
# SK      110
# NL      107
# MY      105
# AO      104
# ZM      103
# Name: iso_country, dtype: int64

# %%
21 ** 3
# Out:
# 9261

# %%
31 ** 3
# Out:
# 29791

# %%
41 ** 3
# Out:
# 68921

# %%
import pandas as pd
df = pd.read_parquet('airportposition.parquet')

# %%
df.head()
# Out:
#    Rec #.      id ident           type                                name  \
# 0       1    6523   00A       heliport                   Total Rf Heliport
# 1       2  323361  00AA  small_airport                Aero B Ranch Airport
# 2       3    6524  00AK  small_airport                        Lowell Field
# 3       4    6525  00AL  small_airport                        Epps Airpark
# 4       5    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601            11      None          US      US-PA
# 1     38.704022    -101.473911          3435      None          US      US-KS
# 2     59.949200    -151.695999           450      None          US      US-AK
# 3     34.864799     -86.770302           820      None          US      US-AL
# 4     35.608700     -91.254898           237      None          US      US-AR
#
# ...

# %%
df.head()
# Out:
#    Rec #.      id ident           type                                name  \
# 0       1    6523   00A       heliport                   Total Rf Heliport
# 1       2  323361  00AA  small_airport                Aero B Ranch Airport
# 2       3    6524  00AK  small_airport                        Lowell Field
# 3       4    6525  00AL  small_airport                        Epps Airpark
# 4       5    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601            11      None          US      US-PA
# 1     38.704022    -101.473911          3435      None          US      US-KS
# 2     59.949200    -151.695999           450      None          US      US-AK
# 3     34.864799     -86.770302           820      None          US      US-AL
# 4     35.608700     -91.254898           237      None          US      US-AR
#
# ...

# %%
af.to_parquet('airportposition.parquet.gzip',compression='gzip')

# %%
ff = pd.read_parquet('flights.parquet.gzip')

# %%
flightResult = ff[ff['icao_dep'] == 'KLAX']

# %%
flightResult = flightResult[flightResult['weekdayId'] == 2]

# %%
flightResult
# Out:
#                           airline icao_dep icao_arr          aircraft  \
# 15                         21 Air     KLAX     MMMX    Boeing 767-200
# 236                       ABX Air     KLAX     KCVG  Boeing 767-300ER
# 5129                   Aer Lingus     KLAX     EIDW       Airbus A330
# 6864                     Aeroflot     KLAX     UUEE  Boeing 777-300ER
# 13332   Aeroflot Russian Airlines     KLAX     UUEE  Boeing 777-300ER
# ...                           ...      ...      ...               ...
# 932740           WestJet Airlines     KLAX     CYYC    Boeing 737-700
# 933668           WestJet Airlines     KLAX     CYVR    Boeing 737-700
# 947897            Xiamen Airlines     KLAX     ZSAM      Boeing 787-8
# 952426            Xiamen Airlines     KLAX     ZSAM      Boeing 787-9
# 952881                  XLAirways     KLAX     LFPG   Airbus A330-200
#
#        departing callsign      id  weekdayId tailnum
# 15         08:20  CSB2205      15          2  N999YV
# ...

# %%
for a in flightResult['icao_arr'].unique():
    airportResult = af[af['ident'] == a]
    lat1 = airportResult['latitude_deg'].array
    print(lat1[0])
# Out:
# 19.4363
# 39.0488014221
# 53.421299
# 55.972599
# 20.52179908752
# 25.7784996033
# 29.0958995819
# 20.6173
# 50.033333
# 49.193901062
# 51.113899231
# 45.4706001282
# 43.6772003174
# 40.08010101318
# 31.14340019226
# 49.012798
# -17.553699
# -37.0080986023
# 51.4706
# 47.449001
# 47.90629959
# 45.58869934
# 37.362598
# 38.50899887
# 19.1448001862
# 40.63980103
# 23.1613998413
# 36.08010101
# 40.69250106812
# 42.36429977
# 23.15180015564
# 61.17440032959
# 10.5933
# 21.32062
# 9.993860244751
# 38.8521
# 37.6189994812
# 39.1754
# 39.87189865112
# 26.072599
# 20.8986
# 41.9786
# 38.94449997
# 40.78839874268
# 32.847099
# 20.68009948731
# 41.8002778
# 45.77750015
# 43.5820007324
# 41.88470077515
# 46.92070007324
# 37.649899
# 34.7294006348
# 36.281898
# 35.7647018433
# 35.552299
# 25.79319953919
# 38.1744
# 30.19449996948
# 29.98439979553
# 39.998001
# 35.87760162354
# 22.308901
# 32.896801
# -33.94609832764
# -34.8222
# 33.43429946899
# 28.42939949036
# 21.97599983215
# 19.738783
# ...

# %%
af[af['ident'] == 'KDEN']
# Out:
#        Rec #.    id ident           type                          name  \
# 26929   26929  3486  KDEN  large_airport  Denver International Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 26929     39.861698    -104.672997          5431      None          US
#
#       iso_region municipality scheduled_service gps_code  iata_code  \
# 26929      US-CO       Denver                ye     KDEN          0
#
#       local_code  home_link  wikipedia_link  keywords
# 26929        DEN          0               0         0

# %%
af[af['ident'] == 'KFCA']
# Out:
# Empty DataFrame
# Columns: [Rec #., id, ident, type, name, latitude_deg, longitude_deg, elevation_ft, continent, iso_country, iso_region, municipality, scheduled_service, gps_code, iata_code, local_code, home_link, wikipedia_link, keywords]
# Index: []

# %%
speedData = pd.read_parquet('aircraftspeed.parquet')

# %%
B738 = speedData[speedData['ICAOaircraft'] == 'B738']

# %%
205/460
# Out:
# 0.44565217391304346

# %%
0.44565*60
# Out:
# 26.739

# %%
distance1 = 80
distance2 = 205-80

# %%
speed1 = int(B738.Climb2)
speed2 = int(B738.Cruise)

# %%
time1 = distance1/speed1

# %%
time1
# Out:
# 0.27586206896551724

# %%
time2 = distance2/speed2

# %%
time2
# Out:
# 0.2717391304347826

# %%
time=time1+time2

# %%
time
# Out:
# 0.5476011994002998

# %%
time *= 60

# %%
time
# Out:
# 32.85607196401799
